# %% [markdown]
# <a href="https://colab.research.google.com/github/iarbietonilsson/food_sales_predictions/blob/main/DataScienceFoodSalesPredictions_Ingrid_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Food Sales Predictions
#
#
# ---
#
# *  ### Ingrid Arbieto Nelson

# %% [markdown]
# ## **Overview:**
#
# ---
#
#
#
# This is an overview of the steps you will need to complete for part one of the project. There are more detailed instructions for each section following the overview.
#
# 1) Create a GitHub Account
#
# 2) Set up a GitHub repository that will house your first portfolio project.
#
# 3) Add Markdown cells with your name and section headers to the notebook.
#
# 4) Add the Google Colab Notebook to your GitHub repository.
#
# 5) Submit the link to your GitHub repo!
#
# <br />
#
#
# ***
#
# <br />
#
#
# We will continue to work off of the GitHub repository you created last week for your first portfolio project. The goal of your portfolio projects are to have items to show potential employers that demonstrate your data science skills and competencies.
#
# The first project will be a sales prediction for food items sold at various stores. The goal of this is to help the retailer understand the properties of products and outlets that play crucial roles in increasing sales.
#
# <br />
# <center>
#
# ![image](https://drive.google.com/uc?id=1KBhOlprSFdBN12iuVTLqHszs3NhCa3AH)
#
# </center>
#
# <br />
#
# For the next part, your task is to use Pandas to load in the data and start exploring and cleaning it.  As data scientists, about [**80% of our time is spent on data preparation**](https://www.forbes.com/sites/gilpress/2016/03/23/data-preparation-most-time-consuming-least-enjoyable-data-science-task-survey-says/?sh=6d56cc4d6f63) - so this is a very important step!
#
# <br />
#
# *   Download the data using the link on the Learning Platform.
#     *   (Note: [Original data source](https://datahack.analyticsvidhya.com/contest/practice-problem-big-mart-sales-iii/)).
# *   Insert code below the heading "Loading Data"
#     *   Use Pandas to read the sales prediction data set into Google Colab.
#     *   Use df.info() and df.head() methods to preview the first rows of your data and a summary of your DataFrame's columns.
# *   Insert code below the heading "Data Cleaning"
#     *   Explore the data - what do you need to do to clean this data? Clean it!
#     *   Be sure to address each of the following tasks:
#
#         1) How many rows and columns?
#
#         2) What are the datatypes of each variable?
#
#         3) Are there duplicates? If so, drop any duplicates.
#
#         4) Identify missing values.
#
#         5) Decide on how to address the missing values and do it! (This requires your judgement, so explain your choice).
#
#         6) Confirm that there are no missing values after addressing them.
#
#         7) Find and fix any inconsistent categories of data (example: fix cat, Cat, and cats so that they are consistent).
#
#         8) For any numerical columns, obtain the summary statistics of each (min, max, mean).
#
#     Here are a few resources to help you consider more advanced ways to deal with missing values in your dataset (check out the optional additional Pandas resources at the end of this Chapter for more resources on this):
#     *   [Missing Data, its types, and statistical methods to deal with it.](https://medium.com/@raoufkeskes/missing-data-its-types-and-statistical-methods-to-deal-with-it-5cf8b71a443f#id_token=eyJhbGciOiJSUzI1NiIsImtpZCI6IjAyYTYxZWZkMmE0NGZjMjE1MTQ4ZDRlZmZjMzRkNmE3YjJhYzI2ZjAiLCJ0eXAiOiJKV1QifQ.....kZLlrhvJp0E2Rc1Kz_c4UjZ7De2E9D81MNlbouBxBJxglhhzU3ATfGO9ThjngyRmT6pDjF0JcYqmn8U-zEOEuy2PXWCGKPt056e0UYgvTAHqXR7bjbYNKWOV256ntYv2utaurDRT3d09SFO12Gh2Ou9pHvAvp-3YtrMHwQYdQFHuaedKfKSQDEad_38SbnFUIGYnMRfAJGBQpNEwz_11fMK2KnaKPMdFm9MVkWLh776r_t1GEvY-FYEvCcOvf_yQo0mzNdXA6HtPO_tNVVDj3BYCyvMKhHNdJXWUo9Y9EaQuGhF3DwvIVUP9dRecRIJoWpLclb8xoypfNIh6ID_iWQ)
#     *   [6 Different Ways to Compensate for Missing Values In a Dataset.](https://https://towardsdatascience.com/6-different-ways-to-compensate-for-missing-values-data-imputation-with-examples-6022d9ca0779)
#     *   [Dealing with missing data: Key assumptions and methods for applied analysis.](https://chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.bu.edu/sph/files/2014/05/Marina-tech-report.pdf)
#     *   Feel free to use any other resources or techniques you find online that you think are appropriate/useful.

# %% [markdown]
# ##Data Dictionary<a name="Data Dictionary">
#
# <center>
#
# ![image](https://drive.google.com/uc?id=1kdsKuuQa6PA5zx6PcI_J7amlONsbFaXj)
#
# </center>

# %% [markdown]
# ## Loading Data<a name = "Loading Data">

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSZM_GiLJAcSH0K70Pp1eG_J_-wht9ScYsPsaJ9IstEA2OuEYpCi4_lk6KBLc99MIA0V97E-Hs-Z84y/pub?gid=415579051&single=true&output=csv'
df = pd.read_csv(url)

# %%
df2 = df.copy()

# %%
# view header - 1st 5 rows
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### **1  Size of Dataframe**
#
# ---
#
#
#
# Use df.shape() to determine how many rows and columns in the dataframe.
# *   There are 8,523 rows and 12 columns.

# %%
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# ### **2  Data Types**
#
# ---
#
#
#
# Check data types for each variable.

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# ### **3   Duplicates / Drop Irrelevant Data**
#
# ---
#
#
#
#
# #### **Duplicates**
#
#
#
# Drop any duplicates, i.e. data entries that are exactly the same across all columns.
# *   There are no duplicate data entries.

# %%
# Check for duplicated data in Python
df.duplicated().any()
# Out:
# False

# %%
# Count any duplicate entries
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Identify Irrevalent Data
#
# ---
#
#
# *such as*
# *   *values that are unique in every row*
# *   *values that are identical across every* row
# *   *an Unnamed column (duplicate index)*
# *   *those that are irrevalent to the task at head*
#
# <br />
#
# ####Analysis -  Which Columns to Drop?

# %% [markdown]
# #### *Item_Identifier*

# %%
# See how many different values for Item_Identifier
df['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
# how many unique item IDs
itemID_length = len(df['Item_Identifier'].value_counts())
itemID_length
# Out:
# 1559

# %%
# show how many unique item IDs in readable format
print(f'There are {itemID_length} unique items with irrevalent alphanumeric IDs, so good to delete.')
# Out:
# There are 1559 unique items with irrevalent alphanumeric IDs, so good to delete.

# %% [markdown]
# #### *Outlet_Identifier*

# %%
# See how many different values for Outlet_Identifier
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
# how many outlet IDs
outletID_length = len(df['Outlet_Identifier'].value_counts())
outletID_length
# Out:
# 10

# %%
# display outlet ID results in readable format
print(f'Although there are only {outletID_length} unique outlet IDs, these values seem irrevalent info.')
print('There also are two more descriptive outlet types, seemingly more relevant to sales: outlet size and location!')
# Out:
# Although there are only 10 unique outlet IDs, these values seem irrevalent info.
# There also are two more descriptive outlet types, seemingly more relevant to sales: outlet size and location!

# %% [markdown]
# #### *Outlet_Type*

# %%
# See how many different values for Outlet_Type
df['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
# how many outlet Types
outlet_Type_length = len(df['Outlet_Type'].value_counts())
outlet_Type_length
# Out:
# 4

# %%
# explain judgement call for eliminating Outlet_Type
print(f"Though there are only {outlet_Type_length} kinds of Outlet_Types, there's not much difference between a grocery store and a supermarket, so good to eliminate.")
# Out:
# Though there are only 4 kinds of Outlet_Types, there's not much difference between a grocery store and a supermarket, so good to eliminate.

# %% [markdown]
# #### *Outlet_Establishment_Year*

# %%
# See how many different values for Outlet_Type
df['Outlet_Establishment_Year'].value_counts()
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
# how many different years established for outlets
outlet_year_length = len(df['Outlet_Establishment_Year'].value_counts())
outlet_year_length
# Out:
# 9

# %%
# explain judgement call for eliminating Outlet_Establishment_Year
print(f'Though there are only {outlet_year_length} different establishment years, this does not seem relevant to food sales.')
# Out:
# Though there are only 9 different establishment years, this does not seem relevant to food sales.

# %% [markdown]
# #### **Drop Irrevalent Columns**
#
# ---
#
#
#
# ####*Conclusions*
#
# * Item_Identifiers are unique item IDs, so good to eliminate, as unique in nearly every row, across 1000s of items.
#
# * Outlet Identifiers are also unique, so will delete as well.
#
# * Outlet Type and Outlet Establishment Year do not provide useful data relevant to food sales.

# %%
df.drop(columns = ['Item_Identifier', 'Outlet_Identifier', 'Outlet_Type', 'Outlet_Establishment_Year'], inplace = True)

# %%
# check after dropping columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Weight           7060 non-null   float64
#  1   Item_Fat_Content      8523 non-null   object
#  2   Item_Visibility       8523 non-null   float64
#  3   Item_Type             8523 non-null   object
#  4   Item_MRP              8523 non-null   float64
#  5   Outlet_Size           6113 non-null   object
#  6   Outlet_Location_Type  8523 non-null   object
#  7   Item_Outlet_Sales     8523 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 532.8+ KB

# %% [markdown]
# ### **3b Variables Remaining**
#
# ---
#
# Note that I'm using my judgement with respect to food sales predictions, as I am not a subject matter expert. It is wise to consult with a SME to gain more insights into your data!
#
# Below are the reasons I chose to keep the remaining items:
#
# *   ***Item Weight*** - I chose to keep item weight, as heavier items may cost more. It may not be, but I'm not a SME on food sales.
# *   ***Item Fat Content*** - It may be interesting to compare diet food to yummy fat-full food.
# *   ***Item Visibility*** - If an item is highly visable, it seems more likely that the customer would buy it.
# *   ***Item Type*** - Which food item types sell more!
# *   ***Item_MRP*** - Sales price would definitely be relavant to sales.
# *   ***Outlet Size*** - How big an outlet is seems to relate to how much outlet could sell.
# *   ***Outlet Location*** - Location! Location! Location! - big part of sales
# *   ***Item_Outlet_Sales*** - Primary Sales datapoint!

# %% [markdown]
# ### **4   Identify Missing Values**
#
# ---
#
#
# *   Item weight is missing for 1463 values (17.17%)
# *   Outlet size is missing for for 2410 values (28.28%)

# %%
# Tells number of na's in each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Weight           7060 non-null   float64
#  1   Item_Fat_Content      8523 non-null   object
#  2   Item_Visibility       8523 non-null   float64
#  3   Item_Type             8523 non-null   object
#  4   Item_MRP              8523 non-null   float64
#  5   Outlet_Size           6113 non-null   object
#  6   Outlet_Location_Type  8523 non-null   object
#  7   Item_Outlet_Sales     8523 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 532.8+ KB

# %%
# Sums number of missing values per column
df.isna().sum()
# Out:
# Item_Weight             1463
# Item_Fat_Content           0
# Item_Visibility            0
# Item_Type                  0
# Item_MRP                   0
# Outlet_Size             2410
# Outlet_Location_Type       0
# Item_Outlet_Sales          0
# dtype: int64

# %%
# show percentage of na values / total count of item
df.isna().sum() / len(df) * 100
# Out:
# Item_Weight             17.165317
# Item_Fat_Content         0.000000
# Item_Visibility          0.000000
# Item_Type                0.000000
# Item_MRP                 0.000000
# Outlet_Size             28.276428
# Outlet_Location_Type     0.000000
# Item_Outlet_Sales        0.000000
# dtype: float64

# %% [markdown]
# ### **5 How to Address Missing Values**
#
# ---

# %% [markdown]
# For missing values, I could
# 1.   ***Drop the column***
#      *  ( _good rule of thumb if less than 5%_ )
# 2.   ***Impute the missing value***
#      *  many statistical methods
#      *  simpler one is to use median (_integers_), mean (_float_), mode (_category_)
# 3.   ***Fill in missing value with ```Unknown```***

# %% [markdown]
# #### ***Item Weight***
#
# *   Item Weight is missing for 17.17% of values, so not minimal number of missing values.
# *   Chosen method - **Impute the missing value** with mean for _float_ value
# *   This does introduce errors into the dataset.

# %%
# plot histogram with seaborn including median versus mean
plt.style.use(['seaborn-pastel'])
ax = sns.histplot(data = df, x = 'Item_Weight')
ax.set(title='Item Weight Distribution')
median = df['Item_Weight'].median()
ax.axvline(median,color='red',ls='--',label=f"Median");
mean = df['Item_Weight'].mean()
ax.axvline(mean,color='green',ls='-',label=f"Mean")
ax.legend();

# %%
# determine median and mean
print(df['Item_Weight'].mean())
print(df['Item_Weight'].median())
# Out:
# 12.857645184135976
# 12.6

# %% [markdown]
# *  The distribution for item weight is rather homogeneous across all values.
# *  Both the mean and median are very close in value.
# *  I chose the mean given the weight is continuous floating point value, and the wide value spread.

# %%
# fill missing values with mean for item weight
df['Item_Weight'].fillna(value = df['Item_Weight'].mean(), inplace = True)

# %% [markdown]
# ####***Outlet Size***
# *   Outlet Size has 28.28% missing values, not minimal.
# *   Chosen method - - **Fill in missing value with ```Unknown```** for _category_ value
# *   This does introduce errors into the dataset.

# %%
# Medium is the most common value
df['Outlet_Size'].value_counts(ascending=False)
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
plt.style.use(['seaborn-pastel'])
large_to_small = df.groupby('Outlet_Size').size().sort_values().index[::-1]
ax = sns.countplot(data=df, x = 'Outlet_Size', order=large_to_small);

# %% [markdown]
# *   Although **```Medium```** is the most common value, 28.28% of ***Outlet Size*** is missing.
# *   There is not much difference between the number of ```Small``` versus ```Medium``` outlets:
#     *   Medium Outlets : 2,793
#     *   Small Outlets: 2,388.
# *   This is why I decided to fill with a value of **Unknown**.

# %%
# fill in with Unknown
df['Outlet_Size'].fillna(value = 'Unknown', inplace = True)

# %%
# check count of data for Outlet Size after filling in with Unknown
large_to_small = df.groupby('Outlet_Size').size().sort_values().index[::-1]
ax = sns.countplot(data=df, x = 'Outlet_Size', order=large_to_small);

# %% [markdown]
# #### * **Note**: **```Unknown```** is the 2nd largest count!

# %% [markdown]
# ### **6  Final check for Missing Values**
#
# ---
#
#
#
# Check the info on the dataframe to ensure there are no longer any missing values!!

# %%
# Check that all values filled in
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Weight           8523 non-null   float64
#  1   Item_Fat_Content      8523 non-null   object
#  2   Item_Visibility       8523 non-null   float64
#  3   Item_Type             8523 non-null   object
#  4   Item_MRP              8523 non-null   float64
#  5   Outlet_Size           8523 non-null   object
#  6   Outlet_Location_Type  8523 non-null   object
#  7   Item_Outlet_Sales     8523 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 532.8+ KB

# %% [markdown]
# ### **7  Find and fix any Inconsistent Categories of Data**
#
# ---
#
#
#
# ####***Numerical***
#
# From data info above, floats look consistent with data dictionary:
# *   Item Weight
# *   Item Visability
# *   Item_MRP
# *   Item_Outlet_Sales
#
# ####***Categorical***
#
# Next, check categorical values for inconsistent data.

# %%
# find string data 
data_types = df.dtypes
str_cols = data_types[data_types=='object'].index
str_cols
# Out:
# Index(['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type'], dtype='object')

# %%
# loop through string data to inspect for inconsistent values
for col in str_cols:
   print(f'= {col}:')
   print(df[col].value_counts(dropna=False))
   print("\n\n")
# Out:
# = Item_Fat_Content:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
#
#
# = Item_Type:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
#
#
# = Outlet_Size:
# Medium     2793
# Unknown    2410
# Small      2388
# High        932
# Name: Outlet_Size, dtype: int64
#
#
#
# = Outlet_Location_Type:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %% [markdown]
# *   Only **Item Fat Content** has inconsistent values, per the data dictionary.

# %% [markdown]
# ####***Item Fat Content***

# %%
# values for item fat content
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
# replace inconsistent values for item fat content
df.replace(['LF','low fat'], ['Low Fat', 'Low Fat'], inplace = True)
df.replace(['reg'], ['Regular'], inplace = True)

# %%
# check after replacing for consistent values
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# ### **8 Summary Statistics for Numeric Features**
#
# ---

# %%
# summary statistics for numerical values
df.describe().round(2)
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# count      8523.00          8523.00   8523.00            8523.00
# mean         12.86             0.07    140.99            2181.29
# std           4.23             0.05     62.28            1706.50
# min           4.56             0.00     31.29              33.29
# 25%           9.31             0.03     93.83             834.25
# 50%          12.86             0.05    143.01            1794.33
# 75%          16.00             0.09    185.64            3101.30
# max          21.35             0.33    266.89           13086.96

# %%
# another way to show min, max, & mean
summary_stats = df.describe()
summary_stats.loc[['min','max','mean']]
# Out:
#       Item_Weight  Item_Visibility    Item_MRP  Item_Outlet_Sales
# min      4.555000         0.000000   31.290000          33.290000
# max     21.350000         0.328391  266.888400       13086.964800
# mean    12.857645         0.066132  140.992782        2181.288914

# %% [markdown]
# # **Exploratory Visuals and Analysis** <a name="Exploratory Visuals and Analysis">
#
# ---
#
#
#
#
# > For Part 3, your task is to complete any statistical analyses that might help you understand, explain, or model with your data. This must include at least one of each:
#
# * Histogram to view the distributions of various features in your dataset.
# * Boxplot to view statistical summaries of various features in your dataset.
# * Heatmap of the correlation between features.
#
# Please feel free to add more than the minimum. Remember this is your chance to display your skills!

# %% [markdown]
# * There are many different ways to explore data.
# * EDA allows us to explore our data, and get a better understanding of trends, features of the data.

# %%
# check data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Weight           8523 non-null   float64
#  1   Item_Fat_Content      8523 non-null   object
#  2   Item_Visibility       8523 non-null   float64
#  3   Item_Type             8523 non-null   object
#  4   Item_MRP              8523 non-null   float64
#  5   Outlet_Size           8523 non-null   object
#  6   Outlet_Location_Type  8523 non-null   object
#  7   Item_Outlet_Sales     8523 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 532.8+ KB

# %% [markdown]
# ###**Numerical**
#
#
# ---
#
#
# * For each numerical feature, we will plot the distribution, as well as a boxplot.
# * Boxplots will tell us if there are any outliers.

# %%
# find numerical column names
num_cols = df.select_dtypes('number').columns
num_cols
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales'], dtype='object')

# %%
def plot_numeric(df,col):
  """EDA function to plot histogram and boxplot for selected column"""
  # figure and axes share same x-axis
  fig, axes = plt.subplots(nrows=2,figsize=(10,5),sharex=True)

  # seaborn plots with axes[i]
  sns.histplot(data=df,x=col,ax=axes[0])
  # plot shows mean value
  mean_value=df[col].mean()
  axes[0].axvline(mean_value,color='purple',ls='--',
                  label=f"Mean Value = ${mean_value:,.2f}",);
  # plot shows median value
  median_value = df[col].median()
  axes[0].axvline(median_value,color='k',ls='-',
                  label=f"Median Value = ${median_value:,.2f}");
  sns.boxplot(data=df, x = col, ax = axes[1])

  # title for top graph
  axes[0].set_title(f'EDA for {col}')

  # format to save figure plot to not be cutoff
  plt.tight_layout()
  plt.show()

# %% [markdown]
# ####***EDA for Food Item Outlet Sales***

# %%
plot_numeric(df,'Item_Outlet_Sales')

# %% [markdown]
# *  Histogram skews to the right.
# *  There are a number of outliers for food item sales, likely due to large variety of foods, number of items.

# %% [markdown]
# ####***EDA for Food Item Weight***

# %%
plot_numeric(df,'Item_Weight')

# %% [markdown]
# *  The average weight and median weight value is very close in value, practically the same.
# *  There is a broad distribution of weights.

# %% [markdown]
# ####***EDA for Food Item Retail Price***

# %%
plot_numeric(df,'Item_MRP')

# %%
# average retail price
df['Item_MRP'].mean()
# Out:
# 140.9927819781767

# %% [markdown]
# *  There is a wide range of retail prices.
# *  The average retail price and median value are close in value.

# %% [markdown]
# ####***EDA for Food Item Visibility***

# %%
plot_numeric(df,'Item_Visibility')

# %% [markdown]
# * The percentage of store area for most products is quite low, between approximately 3% to 9%.
# * There are a large number of outlier values, with visibility above the 75th percentile, around 20%.

# %% [markdown]
# ###**Categorical**
#
# ---
#
#
# ####Visualizing with Barplots
#
# * Barplots can be used to show the categorical counts of data.

# %%
# create function to plot a barplot
def plot_bar(data,x,y,figsize=(10,5)):
  # sets the figure size
  fig, ax = plt.subplots(figsize=figsize)
  
  # determine the value counts for each category, sort in descending order
  counts = df[x].value_counts().sort_values(ascending=False).to_frame()

  # plot barplot
  sns.barplot(data=counts, x=counts.index, y=counts[x],ax=ax)

  # show x axis labels at 90 degrees so don't run together
  plt.xticks(rotation=90)
  # set title, x axis , & y axis
  ax.set_title(f'Categorical Frequencies of {y}',fontsize=20, fontweight='bold');
  ax.set_xlabel(f'Categories for {y}', fontsize=15, fontweight = 'bold')
  ax.set_ylabel('Counts',fontsize=15, fontweight='bold')
  
  return fig,ax

# %% [markdown]
# ####***Categorical Frequency for Food Item Fat Content***

# %%
fig, ax = plot_bar(df, 'Item_Fat_Content','Item Fat Content');
plt.show()
print(df['Item_Fat_Content'].value_counts())
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# * There are nearly twice as many Low Fat food items than Regular or more fat content.

# %% [markdown]
# ####***Categorical Frequency for Food Item Type***
#
# ***

# %%
fig, ax = plot_bar(df, 'Item_Type','Item Type');
plt.show()
print(df['Item_Type'].value_counts())
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %% [markdown]
# * Fruits & vegetables, Snacks, and Household items, such as toilet paper, are the top 3 items sold!
# * Seafood is the least food item sold.

# %% [markdown]
# ####***Categorical Frequency for Outlet Size***

# %%
fig, ax = plot_bar(df, 'Outlet_Size','Outlet Size');
plt.show()
print(df['Outlet_Size'].value_counts())
# Out:
# Medium     2793
# Unknown    2410
# Small      2388
# High        932
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# * High or presumably large Outlet Size is the least common size of Outlet store.
# * The unknown or missing values correlates with Small Outlet size, but without subject matter expertise, it is hard to know the true missing values.

# %% [markdown]
# ####***Categorical Frequency for Outlet Size***

# %%
fig, ax = plot_bar(df, 'Outlet_Location_Type','Outlet Location Type');
plt.show()
print(df['Outlet_Location_Type'].value_counts())
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %% [markdown]
# * There are more Tier 3 than Tier 1 locations. This implies there are less top locations.
# * The Outlet Location Type decreases in number moving towards the top tiers.

# %% [markdown]
# ### **Food Item Outlet Sales by Item Type**
#
# ---

# %%
# group average food item sales by item type
foodItem_sales = df.groupby('Item_Type')['Item_Outlet_Sales'].mean().reset_index()
foodItem_sales
# Out:
#                 Item_Type  Item_Outlet_Sales
# 0            Baking Goods        1952.971207
# 1                  Breads        2204.132226
# 2               Breakfast        2111.808651
# 3                  Canned        2225.194904
# 4                   Dairy        2232.542597
# 5            Frozen Foods        2132.867744
# 6   Fruits and Vegetables        2289.009592
# 7             Hard Drinks        2139.221622
# 8      Health and Hygiene        2010.000265
# 9               Household        2258.784300
# 10                   Meat        2158.977911
# 11                 Others        1926.139702
# 12                Seafood        2326.065928
# 13            Snack Foods        2277.321739
# 14            Soft Drinks        2006.511735
# 15          Starchy Foods        2374.332773

# %%
# sort in descending order
foodItem_sales = foodItem_sales.sort_values(by='Item_Outlet_Sales',ascending=False)
foodItem_sales
# Out:
#                 Item_Type  Item_Outlet_Sales
# 15          Starchy Foods        2374.332773
# 12                Seafood        2326.065928
# 6   Fruits and Vegetables        2289.009592
# 13            Snack Foods        2277.321739
# 9               Household        2258.784300
# 4                   Dairy        2232.542597
# 3                  Canned        2225.194904
# 1                  Breads        2204.132226
# 10                   Meat        2158.977911
# 7             Hard Drinks        2139.221622
# 5            Frozen Foods        2132.867744
# 2               Breakfast        2111.808651
# 8      Health and Hygiene        2010.000265
# 14            Soft Drinks        2006.511735
# 0            Baking Goods        1952.971207
# 11                 Others        1926.139702

# %%
# plot a bar plot showing average food sales by item type
plt.figure(figsize=(12,8))
sns.barplot(data=foodItem_sales,x='Item_Outlet_Sales', y='Item_Type');
plt.title('Average Food Sales by Item Type',fontsize=18,fontweight='bold');

# %% [markdown]
# *  The average sales top items are starchy foods (such as bread), seafood,and fruits & vegetables.
# * Baking Goods are one of the least sold items, while Snacks are top of the list! Given that it takes a good amount of time to cook versus relaxing with snack food makes logical sense!

# %% [markdown]
# ### **Food Item Price by Item Type**
#
# ---

# %%
# group average item price by item type
avg_price = df.groupby('Item_Type')['Item_MRP'].mean().reset_index()
avg_price
# Out:
#                 Item_Type    Item_MRP
# 0            Baking Goods  126.380766
# 1                  Breads  140.952669
# 2               Breakfast  141.788151
# 3                  Canned  139.763832
# 4                   Dairy  148.499208
# 5            Frozen Foods  138.503366
# 6   Fruits and Vegetables  144.581235
# 7             Hard Drinks  137.077928
# 8      Health and Hygiene  130.818921
# 9               Household  149.424753
# 10                   Meat  139.882032
# 11                 Others  132.851430
# 12                Seafood  141.841719
# 13            Snack Foods  146.194934
# 14            Soft Drinks  131.492506
# 15          Starchy Foods  147.838023

# %%
# sort in descending order
avg_price = avg_price.sort_values(by='Item_MRP',ascending=False)
avg_price
# Out:
#                 Item_Type    Item_MRP
# 9               Household  149.424753
# 4                   Dairy  148.499208
# 15          Starchy Foods  147.838023
# 13            Snack Foods  146.194934
# 6   Fruits and Vegetables  144.581235
# 12                Seafood  141.841719
# 2               Breakfast  141.788151
# 1                  Breads  140.952669
# 10                   Meat  139.882032
# 3                  Canned  139.763832
# 5            Frozen Foods  138.503366
# 7             Hard Drinks  137.077928
# 11                 Others  132.851430
# 14            Soft Drinks  131.492506
# 8      Health and Hygiene  130.818921
# 0            Baking Goods  126.380766

# %%
# plot a bar plot showing average food item price by item type
plt.figure(figsize=(12,8))
sns.barplot(data=avg_price,x='Item_MRP', y='Item_Type');
plt.title('Average Food Item Price by Item Type',fontsize=18,fontweight='bold');

# %% [markdown]
# *  The average top price items are household, dairy, and starchy foods, such as bread.
# * Baking Goods are the least pricey item, while Snacks are in pricier, near the top of the list! Baking Goods are ingredients, not cooked. Given that it takes a good amount of time to cook versus relaxing with snack food makes logical sense!

# %% [markdown]
# ### **EDA for Correlated Features**
#
# ---
#
# ####Food Item Sales by Price & Outlet Size

# %%
sns.scatterplot(data=df, x='Item_MRP', y='Item_Outlet_Sales',hue='Outlet_Size');

# %% [markdown]
# *  This scatter plot shows the moderate correlation between Food Item Price and Food Item Sales.
# *  There are more sales at Medium sized stores, which correlates with the highest number of Medium-sized stores.

# %%
sns.lmplot(data=df, x='Item_MRP',y='Item_Outlet_Sales',hue='Outlet_Size');

# %% [markdown]
# * This lmplot shows the line of best fit. This helps correlate the Outlet Size data fit.
# * Again, you can see the moderate positive correlation between Food Item Retail Price and Food Item Sales.

# %% [markdown]
# ### **ScatterPlots**
#
# ---
#
#
# ####Food Item Sales by Item Type

# %%
# create filter for dataframe where Item Type is Dairy
dairy_filter = df['Item_Type'] == 'Dairy'

# find dataframe for Dairy items
dairy = df.loc[dairy_filter,:]

# plot lmplot of Price vs Sales for Dairy
sns.lmplot(data=dairy, x='Item_MRP', y='Item_Outlet_Sales');

# %%
# create filter for dataframe where Item Type is Starchy Foods
starch_filter = df['Item_Type'] == 'Starchy Foods'

# find dataframe for Starchy Food items
starch = df.loc[starch_filter,:]

# plot lmplot of Price vs Sales for Starchy Foods
sns.lmplot(data=starch, x='Item_MRP', y='Item_Outlet_Sales');

# %%
sns.lmplot(data=df, x='Item_MRP',y='Item_Outlet_Sales',hue='Item_Type');

# %% [markdown]
# ### **HeatMap**
#
# ---

# %%
sns.heatmap(df.corr(),annot=True,cmap='Purples');

# %% [markdown]
# * The only item with correlation is between Item Retail Price and Food Item Sales. These are moderately correlated.
# * Other variables show no correlation.

# %% [markdown]
# # **Explanatory Visuals & Analysis** <a name="Explanatory Visuals & Analysis">
#
# ---
#
#
# The goal of this is to help the retailer understand the properties of products and outlets that play crucial roles in increasing sales.
#
# > For Part 4, your task is to build several data visualizations to help your stakeholders better understand trends in the data. Feel free to get creative with this week - this is your chance to set your project apart from others with exceptional visualizations and analyses.
#
# * Build on your previous cleaning, exploration, and analysis.
# * Create a minimum of two data visualizations that help others understand trends in the data (explanatory data analysis).
# * Since these graphs are for reporting purposes, make sure they look nice by including titles, legends, etc.

# %% [markdown]
# ## **Possible Questions to Answer:**
# #### 1. What are the Top Items sold?
# #### 2. Is there a correlation between Food Item Sales and Item Price?
# #### 3. Is there a correlation between Food Item Sales and Item Price by Outlet Size?

# %% [markdown]
# ### **Top Food Items Sold**
#
# ---
#
# * #### How many are sold for each Item Type

# %%
fig, ax = plot_bar(df, 'Item_Type','Item Type');
plt.show()
#print(df['Item_Type'].value_counts())

# %% [markdown]
# #### **1. What are the Top Items sold?**
#
# ---
#
# * #### The top food items sold are
#    * #### **```Fruits and Vegetables```**
#    * #### **```Snack Foods```**
#    * #### **```Household```**
#    * #### **```Frozen Foods```**
#    * #### **```Dairy```**

# %% [markdown]
# ### **Correlation of Food Item Sales to Food Item Price**
#
# ---
#  * #### Compare average food sales and average food item price by Item Type

# %%
# set figure size
plt.figure(figsize=(15,10));

# Subplot 1 of 2 rows, 1 column
plt.subplot(2, 1, 1);

# plot a bar plot showing average food sales by item type
sns.barplot(data=foodItem_sales,x='Item_Outlet_Sales', y='Item_Type');
plt.title('Average Food Sales by Item Type',fontsize=20,fontweight='bold');
plt.xlabel('Average Food Item Sales', fontsize=15, fontweight='bold');
plt.ylabel('Item Type', fontsize=15, fontweight='bold');


# Subplot 2 of 2 rows, 1 column
plt.subplot(2, 1, 2);
sns.barplot(data=avg_price,x='Item_MRP', y='Item_Type');

# plot a bar plot showing average food item price by item type
plt.title('Average Food Item Price by Item Type',fontsize=20,fontweight='bold');
plt.xlabel('Average Food Item Price', fontsize=15, fontweight='bold');
plt.ylabel('Item Type', fontsize=15, fontweight='bold');


# shrink to fit so no overlap between columns
plt.tight_layout()

# %% [markdown]
# #### **2. Is there a correlation between Food Item Sales and Item Price?**
#
# ---
#
# * #### The top average Food sales categories are
#    * #### **```1 Starchy Foods```**
#    * #### **```2 Seafood```**
#    * #### **```3 Fruits and Vegetables```**
#    * #### **```4 Snack Foods```**
#    * #### **```5 Household```**
#    * #### **```6 Dairy```**
# * #### The highest price items are
#    * #### **```1 Household```**
#    * #### **```2 Dairy```**
#    * #### **```3 Starchy Foods```**
#    * #### **```4 Snack Foods```**
#    * #### **```5 Fruits and Vegetables```**
#    * #### **```6 Seafood```**
# * #### The bottom average Food sales categories are
#    * #### **```1 Health and Hygience```**
#    * #### **```2 Soft Drinks```**
#    * #### **```3 Baking Goods```**
#    * #### **```4 Others```**
#
# * #### The lowest price items are
#    * #### **```1 Others```**
#    * #### **```2 Soft Drinks```**
#    * #### **```3 Health and Hygience```**
#    * #### **```4 Baking Goods```**
#
#
# * #### In conclusion, there is a positive correlation between Food Item Sales and Item Price.

# %% [markdown]
# ### **Correlation of Food Item Sales to Food Item Price By Outlet Size**
#
# ---
#  *  Compare average food sales and average food item price by Outlet Size

# %%
# set figure size
plt.figure(figsize=(15,10));
sns.lmplot(data=df, x='Item_MRP',y='Item_Outlet_Sales',hue='Outlet_Size');
plt.title('Food Item Price vs. Sales by Outlet Size', fontsize=15,fontweight='bold');
plt.xlabel('Food Item Price',fontsize=15, fontweight='bold');
plt.ylabel('Food Item Sales',fontsize=15, fontweight='bold');

# %% [markdown]
# * #### This lmplot shows the line of best fit.
# * #### The most sales of food items occurred at Medium-size Outlets.
# * #### Medium supermarket outlets are the most common size.
# * #### Food sales are the highest, based on the most common Supermarket size.
# * #### There is a the moderate positive correlation between Food Item Retail Price and Food Item Sales, by Outlet Size.
# * #### In conclusion, the greater food sales reflect the most common size of Supermarket : Medium-sized Outlets.

# %% [markdown]
# # **Machine Learning PreProcessing** <a name="Machine Learning PreProcessing">
#
# ---
#
# ### ***Use Machine Learning to make Predictions about Future Sales***
#
# For Part 5, you will go back to your original, uncleaned, sales prediction dataset with the goal of preventing data leakage. You should load a fresh version of the original data set here using pd.read_csv() and start your cleaning process over to ensure there is no data leakage!
#
# > ***The goal of this step is to help the retailer by using machine learning to make predictions about future sales based on the data provided.***
#
# * Before splitting your data, you can drop duplicates and fix inconsistencies in categorical data.* *(There is a way to do this after the split, but for this project, you may perform this step before the split)*
# * Identify the features (X) and target (y): Assign the "Item_Outlet_Sales" column as your target and the rest of the relevant variables as your features matrix.
# * Perform a train test split
# * Create a preprocessing object to prepare the dataset for Machine Learning
# * Make sure your imputation of missing values occurs after the train test split using SimpleImputer.

# %% [markdown]
# ### **Imports**
#
# ---

# %%
# Imports 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# imports for machine learning preprocessing
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn import set_config
set_config(display='diagram')

# %% [markdown]
# ### **Reloading the Data**
#
# ---

# %%
df2.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ### **Exploring the Data**
#
# ---

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# #### **Drop Irrevalent Columns**
#
# ---
#
#
# As previously determined, some columns are unique in every row, duplicate to another column, or irrevalent to food sales predictions.
#
#  Columns to Drop:
#
# *  *Item_Identifier*
# *  *Outlet_Identifier*
# *  *Outlet_Type*
# *  *Outlet_Establishment_Year*

# %%
# drop irrevalent columns
df2.drop(columns = ['Item_Identifier', 'Outlet_Identifier', 'Outlet_Type', 'Outlet_Establishment_Year'], inplace = True)

# %%
# check after dropping
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Weight           7060 non-null   float64
#  1   Item_Fat_Content      8523 non-null   object
#  2   Item_Visibility       8523 non-null   float64
#  3   Item_Type             8523 non-null   object
#  4   Item_MRP              8523 non-null   float64
#  5   Outlet_Size           6113 non-null   object
#  6   Outlet_Location_Type  8523 non-null   object
#  7   Item_Outlet_Sales     8523 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 532.8+ KB

# %% [markdown]
# #### **Check for Duplicate, Missing, or Erroneous Data**
#
# ---

# %% [markdown]
# #### ***Duplicates***

# %%
# Check for duplicated data in Python
df2.duplicated().any()
# Out:
# False

# %%
# Count any duplicate entries
df2.duplicated().sum()
# Out:
# 0

# %%
print(f'There are {df2.duplicated().sum()} duplicate values.')
# Out:
# There are 0 duplicate values.

# %% [markdown]
# #### ***Missing Values***

# %%
# see which columns have missing values
df2.isna().sum()
# Out:
# Item_Weight             1463
# Item_Fat_Content           0
# Item_Visibility            0
# Item_Type                  0
# Item_MRP                   0
# Outlet_Size             2410
# Outlet_Location_Type       0
# Item_Outlet_Sales          0
# dtype: int64

# %%
# display total missing values
df2.isna().sum().sum()
# Out:
# 3873

# %%
print(f'There are {df2.isna().sum().sum():,.0f} missing values.')
# Out:
# There are 3,873 missing values.

# %% [markdown]
# #### ***Fixing Inconsistent Values***

# %%
# values for item fat content
df2['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
# replace inconsistent values for item fat content
df2.replace(['LF','low fat'], ['Low Fat', 'Low Fat'], inplace = True)
df2.replace(['reg'], ['Regular'], inplace = True)

# %%
# check after replacing for consistent values
df2['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# #### ***Outliers***
#
# Though *Item_MRP (Price)* has a high max value, it is not too extreme. Note too there are a large number of food items and I am not a subject matter expert on whether these are too high.

# %%
# Display desriptive statistics for all columns
df2.describe(include='all')
# Out:
#         Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# count   7060.000000             8523      8523.000000                   8523
# unique          NaN                2              NaN                     16
# top             NaN          Low Fat              NaN  Fruits and Vegetables
# freq            NaN             5517              NaN                   1232
# mean      12.857645              NaN         0.066132                    NaN
# std        4.643456              NaN         0.051598                    NaN
# min        4.555000              NaN         0.000000                    NaN
# 25%        8.773750              NaN         0.026989                    NaN
# 50%       12.600000              NaN         0.053931                    NaN
# 75%       16.850000              NaN         0.094585                    NaN
# max       21.350000              NaN         0.328391                    NaN
#
# ...

# %% [markdown]
# #### ***Dataframe shape & info***

# %%
df2.shape
# Out:
# (8523, 8)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Weight           7060 non-null   float64
#  1   Item_Fat_Content      8523 non-null   object
#  2   Item_Visibility       8523 non-null   float64
#  3   Item_Type             8523 non-null   object
#  4   Item_MRP              8523 non-null   float64
#  5   Outlet_Size           6113 non-null   object
#  6   Outlet_Location_Type  8523 non-null   object
#  7   Item_Outlet_Sales     8523 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 532.8+ KB

# %%
df2.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Size Outlet_Location_Type  Item_Outlet_Sales
# 0  249.8092      Medium               Tier 1          3735.1380
# 1   48.2692      Medium               Tier 3           443.4228
# 2  141.6180      Medium               Tier 1          2097.2700
# 3  182.0950         NaN               Tier 3           732.3800
# 4   53.8614        High               Tier 3           994.7052

# %% [markdown]
# ### **Define Feature (X) and target (y)**
#
# ---
#
#
# *   assign *'Item_Outlet_Sales'* as target (y)
# *   rest as Feature Matrix (X)

# %%
# define target y
y = df2['Item_Outlet_Sales']
# define features X
X = df2.drop(columns='Item_Outlet_Sales')
X
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
#       Item_MRP Outlet_Size Outlet_Location_Type
# ...

# %% [markdown]
# ### **Validation Split**
#
# ---

# %%
#  split the training & testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
X_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 4776       16.350          Low Fat         0.029565              Household
# 7510       15.250          Regular         0.000000            Snack Foods
# 5828       12.350          Regular         0.158716                   Meat
# 5327        7.975          Low Fat         0.014628           Baking Goods
# 4810       19.350          Low Fat         0.016645           Frozen Foods
# ...           ...              ...              ...                    ...
# 5734        9.395          Regular         0.286345  Fruits and Vegetables
# 5191       15.600          Low Fat         0.117575           Frozen Foods
# 5390       17.600          Low Fat         0.018944     Health and Hygiene
# 860        20.350          Low Fat         0.054363            Snack Foods
# 7270       16.350          Low Fat         0.016993              Household
#
#       Item_MRP Outlet_Size Outlet_Location_Type
# ...

# %% [markdown]
# ### **Identify Feature Types**
#
# ---
#
# * Item_Weight : numerical
# * Item_Fat_Content : nominal
# * Item_Visibility : numerical
# * Item_Type : nominal
# * Item_MRP : numerical
# * Outlet_Size : ordinal
# * Outlet_Location_Type : ordinal

# %% [markdown]
# ### **Instantiate Column Selectors**
#
# ---

# %%
# Instantiate categorical & numerical column selectors or list columns
num_cols = make_column_selector(dtype_include='number')
ord_cols = ['Outlet_Size','Outlet_Location_Type']
nom_cols = ['Item_Fat_Content', 'Item_Type']

# %% [markdown]
# ### **Instantiate Transformers**
#
# ---
#
# * 2 SimpleImputers
#     *  mean strategy
#     *  most frequent strategy
# * Standard Scaler
# * one-Hot Encoder
# * ordinalEncoder

# %%
df2['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df2['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
# instantiate imputer mean & most frequent
mean_imputer = SimpleImputer(strategy='mean')
freq_imputer = SimpleImputer(strategy='most_frequent')

#instantiate Standard Scaler
scaler = StandardScaler()

#instantiate one-Hot Encoder
ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# create replacement dictionaries
outletsize_order = ['Small', 'Medium', 'High']
outletlocation_order = ['Tier 3', 'Tier 2', 'Tier 1']

# instantiate ordinal encoder
ord_enc = OrdinalEncoder(categories=[outletsize_order, outletlocation_order])

# %% [markdown]
# ### **Instantiate Pipelines**
#
# ---
#
# * numerical
# * ordinal categorical
# * nominal categorical

# %%
# Setup the pipelines for the numeric columns
num_pipe = make_pipeline(mean_imputer, scaler)
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %%
# setup pipeline for ordinal categorical columns
ord_cat_pipe = make_pipeline(freq_imputer, ord_enc, scaler)
ord_cat_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('ordinalencoder',
#                  OrdinalEncoder(categories=[['Small', 'Medium', 'High'],
#                                             ['Tier 3', 'Tier 2', 'Tier 1']])),
#                 ('standardscaler', StandardScaler())])

# %%
# setup pipeline for nominal categorical columns
nom_cat_pipe = make_pipeline(freq_imputer, ohe)
nom_cat_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

# %% [markdown]
# ### **Instantiate Column Transformer**
#
# ---

# %%
# Setup the tuples to pair the processors with the make column selectors
num_tuple = (num_pipe, num_cols)
ord_cat_tuple = (ord_cat_pipe, ord_cols)
nom_cat_tuple = (nom_cat_pipe, nom_cols)

# %%
# Instantiate ColumnTransformer
preprocessor = make_column_transformer(num_tuple, ord_cat_tuple, nom_cat_tuple,
                                    remainder='passthrough')
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fc6a64602e0>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   Ordi...egories=[['Small',
#                                                                               'Medium',
# ...

# %% [markdown]
# ### **Fit & Transform Data**
#
# ---

# %%
# Fit the ColumnTransformer on the X_train
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fc6a64602e0>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   Ordi...egories=[['Small',
#                                                                               'Medium',
# ...

# %%
# Transform the X_train and the X_test
X_train_processed = preprocessor.transform(X_train)
X_test_processed  = preprocessor.transform(X_test)

# %% [markdown]
# ### **Inspect Result**
#
# ---

# %%
# Check for missing values and that data is scaled and one-hot encoded
print(np.isnan(X_train_processed).sum().sum(), 'missing values in training data')
print(np.isnan(X_test_processed).sum().sum(), 'missing values in testing data')
print('\n')
print('All data in X_train_processed are', X_train_processed.dtype)
print('All data in X_test_processed are', X_test_processed.dtype)
print('\n')
print('shape of data is', X_train_processed.shape)
print('\n')
X_train_processed
# Out:
# 0 missing values in training data
# 0 missing values in testing data
#
#
# All data in X_train_processed are float64
# All data in X_test_processed are float64
#
#
# shape of data is (6392, 23)
# array([[ 0.81724868, -0.71277507,  1.82810922, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.5563395 , -1.29105225,  0.60336888, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.13151196,  1.81331864,  0.24454056, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.11373638, -0.92052713,  1.52302674, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.76600931, -0.2277552 , -0.38377708, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.81724868, -0.95867683, -0.73836105, ...,  0.        ,
#          0.        ,  0.        ]])

# %% [markdown]
# # **Machine Learning : Regression Models** <a name="Machine Learning : Regression Models">
#
# ---
#
# ### ***Use Machine Learning to Optimize Food Sales Predictions with Regression Models***

# %% [markdown]
# This week, you will finalize your sales prediction project.
# >***The goal of this is to help the retailer understand the properties of products and outlets that play crucial roles in predicting sales.***
#
# 1  Your first task is to build a linear regression model to predict sales.
#
# *  Build a linear regression model.
# * Evaluate the performance of your model based on r^2.
# * Evaluate the performance of your model based on rmse.
#
# 2  Your second task is to build a regression tree model to predict sales.
#
# * Build a simple regression tree model.
# * Compare the performance of your model based on r^2.
# * Compare the performance of your model based on rmse.
#
# 3  You now have tried 2 different models on your data set. You need to determine which model to implement.
#
# * Overall, which model do you recommend?
# * Justify your recommendation.
#
# 4 To finalize this project, complete a README in your GitHub repository including:
#
# * An overview of the project
# * 2 relevant insights from the data (supported with reporting quality visualizations)
# * Summary of the model and its evaluation metrics
# * Final recommendations

# %% [markdown]
# ### **Imports**
#
# ---

# %%
# Imports 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import make_pipeline

# Models
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor

## Regression Metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# set global sci-kit-learn configuration
from sklearn import set_config
set_config(display='diagram')

from IPython.core.display import clear_output

# %% [markdown]
# ### **Reload Processor**
#
# ---

# %%
#display preprocessor
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fc6a64602e0>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   Ordi...egories=[['Small',
#                                                                               'Medium',
# ...

# %% [markdown]
# ### ** Function to Evaluate Models**
#
# ---

# %%
## Create a function to take the true and predicted values
## and print MAE, MSE, RMSE, and R2 metrics
def model_metrics(pipe, X_train, y_train, X_test, y_test, 
                       model_name='Regression Model', ):
  train_pred = pipe.predict(X_train)
  test_preds = pipe.predict(X_test)
  
  metrics = ['train_MAE','test_MAE', 
             'train_RMSE', 'test_RMSE', 
             'train_R2', 'test_R2']
  
  
  ## Train
  train_mae = round(mean_absolute_error(y_train, train_pred),4)
  train_rmse = round(np.sqrt(mean_squared_error(y_train, train_pred)),4)
  train_r2 = round(r2_score(y_train, train_pred),7)

  ## Test
  test_mae = round(mean_absolute_error(y_test, test_preds),4)
  test_rmse = round(np.sqrt(mean_squared_error(y_test, test_preds)),4)
  test_r2 = round(r2_score(y_test, test_preds),7)

  ## Output Dataframe
  scores = pd.DataFrame(index=metrics, columns=[f'{model_name}'])
  scores.loc[metrics, f'{model_name}'] = [train_mae, test_mae,
                                               train_rmse, test_rmse,
                                               train_r2, test_r2]

  return scores

# %% [markdown]
# ### **Linear Regression Model**
#
# ---

# %%
# instantiate Linear Regression model
linreg = LinearRegression()
# create a pipeline
linreg_pipe = make_pipeline(preprocessor,linreg)
# fit model on training data
linreg_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc6a64602e0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='mo...
# ...

# %%
scores_linear = model_metrics(linreg_pipe, X_train=X_train, y_train=y_train, 
                          X_test=X_test, y_test=y_test, 
                           model_name='Linear Regression')

display(scores_linear)
# Out:
#            Linear Regression
# train_MAE          1030.3333
# test_MAE           1008.8091
# train_RMSE         1386.6175
# test_RMSE          1352.7343
# train_R2            0.350317
# test_R2             0.336751

# %% [markdown]
# ### **Regression Tree Model**
#
# ---

# %%
# instantiate decision tree model
dectree = DecisionTreeRegressor(random_state = 42)
# create decision tree pipeline
dectree_pipe = make_pipeline(preprocessor, dectree)
# fit model on training data
dectree_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc6a64602e0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='mo...
# ...

# %%
scores_dt = model_metrics(dectree_pipe, X_train=X_train, y_train=y_train, 
                          X_test=X_test, y_test=y_test, 
                           model_name='Regression_Tree_default')

scores_df = pd.concat([scores_linear,scores_dt], axis=1)

# %%
scores_df
# Out:
#            Linear Regression Regression_Tree_default
# train_MAE          1030.3333                     0.0
# test_MAE           1008.8091               1140.8422
# train_RMSE         1386.6175                     0.0
# test_RMSE          1352.7343               1602.4829
# train_R2            0.350317                     1.0
# test_R2             0.336751                0.069238

# %% [markdown]
# ### **Optimize Regression Tree Model**
#
# ---

# %%
# get default regression tree maximum depth
dectree.get_depth()
# Out:
# 32

# %%
# List of values to try for max_depth:
depths = list(range(2, 32)) # will try every value between 2 and 32

# Data frame to store the score for each value of max_depth:
scores_dt2 = pd.DataFrame(index=depths, columns=['Test Score','Train Score'])
for depth in depths:
    dectree2 = DecisionTreeRegressor(max_depth=depth, random_state=42)
    dectree2_pipe = make_pipeline(preprocessor,dectree2)
    dectree2_pipe.fit(X_train, y_train)
    train_score = dectree2_pipe.score(X_train, y_train)
    test_score = dectree2_pipe.score(X_test, y_test)
    scores_dt2.loc[depth, 'Train Score'] = train_score
    scores_dt2.loc[depth, 'Test Score'] = test_score

# %%
# Visualize which max_depth leads to the highest r2 score
plt.plot(depths, scores_dt2['Test Score'])
plt.xlabel('max_depth')
plt.ylabel('R2');

# %%
# sort R^2 score by testing score
sorted_scores_dt2 = scores_dt2.sort_values(by='Test Score', ascending=False)
sorted_scores_dt2.head()
# Out:
#    Test Score Train Score
# 8    0.480495     0.56938
# 7     0.45191    0.501919
# 9     0.44977    0.605768
# 10   0.428836    0.648367
# 11   0.379219    0.696252

# %%
# display best decision tree depth
best_dt_depth = sorted_scores_dt2.index[0]
print(f'Optimal Depth of Regression Tree is {best_dt_depth}.')
# Out:
# Optimal Depth of Regression Tree is 8.

# %% [markdown]
# ### **Optimal Regression Tree Model**
#
# ---

# %%
# instantiate optimized decision tree model
dectree_opt = DecisionTreeRegressor(max_depth=best_dt_depth, random_state = 42)
# create decision tree pipeline
dectree_opt_pipe = make_pipeline(preprocessor, dectree_opt)
# fit model on training data
dectree_opt_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc6a64602e0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='mo...
#                                                                   ('standardscaler',
# ...

# %%
## Display the Model's metrics
scores_dt_opt = model_metrics(dectree_opt_pipe, X_train=X_train, y_train=y_train, 
                          X_test=X_test, y_test=y_test, 
                           model_name='Regression Tree Optimized')

scores_df = pd.concat([scores_linear,scores_dt,scores_dt_opt], axis=1)

# %%
scores_df
# Out:
#            Linear Regression Regression_Tree_default Regression Tree Optimized
# train_MAE          1030.3333                     0.0                   808.343
# test_MAE           1008.8091               1140.8422                  850.7838
# train_RMSE         1386.6175                     0.0                  1128.893
# test_RMSE          1352.7343               1602.4829                 1197.2062
# train_R2            0.350317                     1.0                   0.56938
# test_R2             0.336751                0.069238                  0.480495

# %% [markdown]
# ### **Bagged Regression Model**
#
# ---

# %%
# Instantiate Bagged Regressor
bagreg = BaggingRegressor(random_state = 42)
# create a pipeline
bagreg_pipe = make_pipeline(preprocessor,bagreg)
# fit on training data
bagreg_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc6a64602e0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='mo...
# ...

# %%
## Display the Model's metrics
scores_br = model_metrics(bagreg_pipe, X_train=X_train, y_train=y_train, 
                          X_test=X_test, y_test=y_test, 
                           model_name='Bagged Tree default')

display(scores_br)
# Out:
#            Bagged Tree default
# train_MAE             351.8635
# test_MAE               888.436
# train_RMSE            527.9399
# test_RMSE            1245.9248
# train_R2               0.90582
# test_R2               0.437354

# %% [markdown]
# ### **Optimize Bagged Regression Model**
#
# ---
#
# * *find best n_estimators (number of estimators)*

# %%
# List of estimator values for Bagged Regressor
estimators = [10, 20, 30, 40, 50, 100]
# Data frame to store the scores
scores_br2 = pd.DataFrame(index=estimators, columns=['Train Score', 'Test Score'])
# Iterate through the values to find the best number of estimators
for num_estimators in estimators:
   bagreg2 = BaggingRegressor(n_estimators=num_estimators, random_state=42)
   bagreg2_pipe = make_pipeline(preprocessor,bagreg2)
   bagreg2_pipe.fit(X_train, y_train)
   train_score = bagreg2_pipe.score(X_train, y_train)
   test_score = bagreg2_pipe.score(X_test, y_test)
   scores_br2.loc[num_estimators, 'Train Score'] = train_score
   scores_br2.loc[num_estimators, 'Test Score'] = test_score

# %%
# Plot Bagged Regressor scores
plt.plot(scores_br2['Test Score'])
plt.show()

# %%
# Sort by test score for Bagged Regressor
sorted_scores_br2 = scores_br2.sort_values(by='Test Score', ascending=False)
sorted_scores_br2
# Out:
#     Train Score Test Score
# 100    0.929614   0.490377
# 50     0.926778   0.480283
# 40     0.925093    0.47462
# 30     0.922753    0.47041
# 20     0.918267   0.461052
# 10      0.90582   0.437354

# %%
# display best number of estimators for Bagged Regressor
best_br_nestimators = sorted_scores_br2.index[0]
print(f'Optimal n estimators of Bagged Tree is {best_br_nestimators}.')
# Out:
# Optimal n estimators of Bagged Tree is 100.

# %% [markdown]
# ### **Optimal Bagged Regression Model**
#
# ---

# %%
# Instantiate optimized Bagged Regressor
bagreg_opt = BaggingRegressor(n_estimators=best_br_nestimators, random_state = 42)
# create a pipeline
bagreg_opt_pipe = make_pipeline(preprocessor,bagreg_opt)
# fit on training data
bagreg_opt_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc6a64602e0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='mo...
#                                                                   ('standardscaler',
# ...

# %%
## Display the Model's metrics
scores_bagregopt = model_metrics(bagreg_opt_pipe, X_train=X_train, y_train=y_train, 
                          X_test=X_test, y_test=y_test, 
                           model_name='Bagged Tree Optimized')

br_scores_df = pd.concat([scores_br, scores_bagregopt], axis=1)

# %% [markdown]
# ### **Bagged Tree Regression Metrics**
#
# ---

# %%
br_scores_df
# Out:
#            Bagged Tree default Bagged Tree Optimized
# train_MAE             351.8635              327.9505
# test_MAE               888.436              855.5724
# train_RMSE            527.9399              456.4025
# test_RMSE            1245.9248             1185.7648
# train_R2               0.90582              0.929614
# test_R2               0.437354              0.490377

# %%
# Comparison of Regression Model Metrics
best_scores_df = pd.concat([scores_linear,scores_dt_opt,scores_bagregopt], axis=1)
best_scores_df
# Out:
#            Linear Regression Regression Tree Optimized Bagged Tree Optimized
# train_MAE          1030.3333                   808.343              327.9505
# test_MAE           1008.8091                  850.7838              855.5724
# train_RMSE         1386.6175                  1128.893              456.4025
# test_RMSE          1352.7343                 1197.2062             1185.7648
# train_R2            0.350317                   0.56938              0.929614
# test_R2             0.336751                  0.480495              0.490377

# %% [markdown]
# ### **Random Forest Regression Model**
#
# ---

# %%
# Instantiate Random Forest
rf = RandomForestRegressor(random_state = 42)
# create random forest pipeline
rf_pipe = make_pipeline(preprocessor, rf)
# fit on training data
rf_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc6a64602e0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='mo...
# ...

# %%
## Display the Model's metrics
scores_rf = model_metrics(rf_pipe, X_train=X_train, y_train=y_train, 
                          X_test=X_test, y_test=y_test, 
                           model_name='Random Forest default')

display(scores_rf)
# Out:
#            Random Forest default
# train_MAE               327.6588
# test_MAE                855.6146
# train_RMSE               456.167
# test_RMSE              1185.8003
# train_R2                0.929687
# test_R2                 0.490347

# %% [markdown]
# ### **Optimize Random Forest**
#
# ---
# * *find best max_depth*
# * *find best n_estimators (number of estimators)*

# %%
# find max depth
est_depths = [estimator.get_depth() for estimator in rf.estimators_]
max(est_depths)
# Out:
# 38

# %%
# test a range of max depths
depths = range(1, max(est_depths))
scores_rf2 = pd.DataFrame(index=depths, columns=['Test Score'])
for depth in depths:    
   model = RandomForestRegressor(max_depth=depth,random_state=42)
   model_pipe = make_pipeline(preprocessor,model)
   model_pipe.fit(X_train, y_train)
   scores_rf2.loc[depth, 'Train Score'] = model_pipe.score(X_train, y_train)
   scores_rf2.loc[depth, 'Test Score'] = model_pipe.score(X_test, y_test)

# %%
plt.plot(scores_rf2['Test Score'])

# %%
# sort max depth optimized scores by highest test score
sorted_scores_rf2 = scores_rf2.sort_values(by='Test Score', ascending=False)
sorted_scores_rf2.head()
# Out:
#    Test Score  Train Score
# 9    0.531433     0.655286
# 8    0.527549     0.608925
# 10   0.527338     0.704487
# 11   0.523681     0.751099
# 12   0.518761     0.793667

# %%
# display best maximum depth for random forest
best_depth_rf = sorted_scores_rf2.index[0]
print(f'The best depth for the Random Forest Model is {best_depth_rf}.')
# Out:
# The best depth for the Random Forest Model is 9.

# %%
# choose a couple of values for n_estimators to save time
# you can use another loop later to narrow down the best number
# by trying numbers close to the best one
n_ests = [50, 100, 150, 200, 250]
scores3_rf = pd.DataFrame(index=n_ests, columns=['Test Score', 'Train Score'])
for n in n_ests:
   model2 = RandomForestRegressor(max_depth=best_depth_rf, n_estimators=n,random_state=42)
   model2_pipe = make_pipeline(preprocessor,model2)
   model2_pipe.fit(X_train, y_train)
   scores3_rf.loc[n, 'Train Score'] = model2_pipe.score(X_train, y_train)
   scores3_rf.loc[n, 'Test Score'] = model2_pipe.score(X_test, y_test)

# %%
plt.plot(scores3_rf['Test Score'])
plt.xticks(n_ests);

# %%
# sort best scores for max depth & number of estimators by highest test score
sorted_scores3_rf = scores3_rf.sort_values(by='Test Score', ascending=False)
sorted_scores3_rf.head()
# Out:
#     Test Score Train Score
# 150   0.534068    0.656514
# 250   0.533223    0.657018
# 200    0.53259    0.656038
# 100   0.531433    0.655286
# 50    0.528281    0.655479

# %%
# display best max depth & number of estimators
best_rf_nest = sorted_scores3_rf.index[0]
print(f'For the Random Forest Model, the best depth is {best_depth_rf} and the best number of estimators is {best_rf_nest}.')
# Out:
# For the Random Forest Model, the best depth is 9 and the best number of estimators is 150.

# %% [markdown]
# ### **Optimal Random Forest Model**
#
# ---

# %%
# Instantiate Random Forest
rf_opt = RandomForestRegressor(max_depth=best_depth_rf, n_estimators=best_rf_nest, random_state = 42)
# create random forest pipeline
rf_opt_pipe = make_pipeline(preprocessor, rf_opt)
# fit on training data
rf_opt_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fc6a64602e0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='mo...
#                                                                    StandardScaler())]),
# ...

# %% [markdown]
# ### **Random Forest Regression Metrics**
#
# ---

# %%
## Display the Model's metrics
scores_rfopt = model_metrics(rf_opt_pipe, X_train=X_train, y_train=y_train, 
                          X_test=X_test, y_test=y_test, 
                           model_name='Random Forest Optimized')

rf_scores_df = pd.concat([scores_rf, scores_rfopt], axis=1)
rf_scores_df
# Out:
#            Random Forest default Random Forest Optimized
# train_MAE               327.6588                738.1806
# test_MAE                855.6146                820.6407
# train_RMSE               456.167               1008.2323
# test_RMSE              1185.8003               1133.7976
# train_R2                0.929687                0.656514
# test_R2                 0.490347                0.534068

# %% [markdown]
# ### **Comparison of Optimized Regression Model Metrics**
#
# ---

# %%
# Comparison of Regression Model Metrics
best_scores_df = pd.concat([scores_linear,scores_dt_opt,scores_bagregopt,scores_rfopt], axis=1)
best_scores_df
# Out:
#            Linear Regression Regression Tree Optimized Bagged Tree Optimized  \
# train_MAE          1030.3333                   808.343              327.9505
# test_MAE           1008.8091                  850.7838              855.5724
# train_RMSE         1386.6175                  1128.893              456.4025
# test_RMSE          1352.7343                 1197.2062             1185.7648
# train_R2            0.350317                   0.56938              0.929614
# test_R2             0.336751                  0.480495              0.490377
#
#            Random Forest Optimized
# train_MAE                 738.1806
# test_MAE                  820.6407
# train_RMSE               1008.2323
# test_RMSE                1133.7976
# train_R2                  0.656514
# test_R2                   0.534068

# %%
df['Item_Outlet_Sales'].median()
# Out:
# 1794.331

# %% [markdown]
# ### **Final Model Selection**
#
# ---
#
# #### The best model to predict Item Outlet Sales is the **Optimized Random Forest Model**.
# * #### The optimized Random Forest Model can account for 53.41% of the variation of the Item Outlet Sales based on the features Item Weight, Item Fat Content, Item Visibility, Item Type, Item MRP (or Sales Price), Outlet Size, and Outlet_Location Type.
# * #### The optimized Random Forest Model has moderate bias, but overall the best R^2 performance on the testing data.
# * #### The optimized Random Forest Model also has the lowest Root Mean Square error (RMSE), 1,133.80. The RSME metric penalizes larger errors more. The RMSE is a better metric to evaluate than the Mean Absolute Error (MAE), as unexpected large errors can be very bad compared to consistent expected errors.
# * #### The median Item Outlet Sales is 1,794.33. On average, the Item Outlet Sales is off by 1,133.80 or 63.18%.
# * #### The Optimized Random Forest model predicts within 1,133.80 of the Item Outlet Sales, which is a low-to-medium correlation. Given the wide variety of items and sales, this seems more of a middle of the road optimized model.
#
# ###**Recommendation**
#
# ---
#
# #### My recommendation is the optimized Random Forest Model is a lowto-medium correlation good predictor of Food Item Sales.
